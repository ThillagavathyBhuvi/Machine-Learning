# %%
#calling the saved model to deploy using pickle. 
import pickle

# %%
# calling the loaded function of the finalized model file to predict the salary.
loaded_model=pickle.load(open("finalized_model_linear.sav",'rb'))
result=loaded_model.predict([[0]])
# Out:
# C:\Users\thila\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# To predict 0years of experiance for salary it gives from bias value.
result
# Out:
# array([[26777.3913412]])
